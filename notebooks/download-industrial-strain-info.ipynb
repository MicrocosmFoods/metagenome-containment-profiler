# %%
import pandas as pd


data = [
    # Lactobacillus (sensu lato)
    {
        "Species/Strain": "Lactobacillus acidophilus NCFM",
        "Typical Use / Role": "Yogurts, fermented milks, supplements",
        "GenBank Accession": "NC_006814.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_006814.1"
    },
    {
        "Species/Strain": "Lactobacillus rhamnosus GG (LGG)",
        "Typical Use / Role": "Yogurt, dairy products, functional foods",
        "GenBank Accession": "NC_013198.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_013198.1"
    },
    {
        "Species/Strain": "Lacticaseibacillus paracasei subsp. paracasei",
        "Typical Use / Role": "Fermented milks, cheese, probiotic drinks",
        "GenBank Accession": "NC_037110.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_037110.1"
    },
    {
        "Species/Strain": "Lacticaseibacillus casei ATCC 334",
        "Typical Use / Role": "Fermented milk drinks (close relative to “Shirota”)",
        "GenBank Accession": "NC_008526.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008526.1"
    },
    {
        "Species/Strain": "Lactiplantibacillus plantarum WCFS1",
        "Typical Use / Role": "Fermented vegetables, sourdough, beverages",
        "GenBank Accession": "NC_004567.2",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_004567.2"
    },
    {
        "Species/Strain": "Lactobacillus reuteri F275",
        "Typical Use / Role": "Probiotic yogurts, infant formulas, supplements",
        "GenBank Accession": "NC_009513.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_009513.1"
    },
    {
        "Species/Strain": "Lactobacillus fermentum IFO 3956",
        "Typical Use / Role": "Fermented cereals, sourdough",
        "GenBank Accession": "NC_010610.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_010610.1"
    },
    {
        "Species/Strain": "Lactobacillus helveticus DPC 4571",
        "Typical Use / Role": "Cheese production (Swiss types), certain yogurts",
        "GenBank Accession": "NC_010080.1",  # Updated link
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_010080.1"
    },
    {
        "Species/Strain": "Lactobacillus delbrueckii subsp. bulgaricus ATCC 11842",
        "Typical Use / Role": "Yogurt starter (w/ Streptococcus thermophilus)",
        "GenBank Accession": "NC_008054.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008054.1"
    },
    {
        "Species/Strain": "Lactobacillus brevis ATCC 367",
        "Typical Use / Role": "Fermented vegetables, pickles, some beers",
        "GenBank Accession": "NC_008497.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008497.1"
    },
    {
        "Species/Strain": "Lactobacillus crispatus ST1",
        "Typical Use / Role": "Occasionally in fermented foods; studied for urogenital health",
        "GenBank Accession": "NC_014106.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014106.1"
    },

    # Bifidobacterium
    {
        "Species/Strain": "Bifidobacterium animalis subsp. lactis BB-12",
        "Typical Use / Role": "Yogurts, cultured dairy, infant formulas",
        "GenBank Accession": "NC_017215.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017215.1"
    },
    {
        "Species/Strain": "Bifidobacterium breve UCC2003",
        "Typical Use / Role": "Infant formulas, some dairy probiotic foods",
        "GenBank Accession": "NC_020517.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_020517.1"
    },
    {
        "Species/Strain": "Bifidobacterium longum subsp. longum NCC2705",
        "Typical Use / Role": "Probiotic yogurts, supplements, infant formulas",
        "GenBank Accession": "NC_004307.2",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_004307.2"
    },
    {
        "Species/Strain": "Bifidobacterium infantis ATCC 15697",
        "Typical Use / Role": "Prevalent in gut of breastfed infants",
        "GenBank Accession": "NC_004579.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_004579.1"
    },
    {
        "Species/Strain": "Bifidobacterium bifidum PRL2010",
        "Typical Use / Role": "Dairy products, probiotic formulations",
        "GenBank Accession": "NC_014638.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_014638.1"
    },

    # Lactococcus
    {
        "Species/Strain": "Lactococcus lactis subsp. lactis IL1403",
        "Typical Use / Role": "Major dairy starter for cheese, etc.",
        "GenBank Accession": "NC_002662.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_002662.1"
    },
    {
        "Species/Strain": "Lactococcus lactis subsp. cremoris SK11",
        "Typical Use / Role": "Flavor development in various cheeses",
        "GenBank Accession": "NC_008527.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008527.1"
    },

    # Other Common Starter/Probiotic Bacteria
    {
        "Species/Strain": "Streptococcus thermophilus LMD-9",
        "Typical Use / Role": "Yogurt co-starter with L. delbrueckii subsp. bulgaricus",
        "GenBank Accession": "NC_008532.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008532.1"
    },
    {
        "Species/Strain": "Bacillus coagulans GBI-30, 6086",
        "Typical Use / Role": "Spore-forming probiotic in shelf-stable products",
        "GenBank Accession": "NZ_CP017674.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NZ_CP017674.1"
    },
    {
        "Species/Strain": "Enterococcus faecium DO",
        "Typical Use / Role": "Occasional use in fermented foods; more controversial as probiotic",
        "GenBank Accession": "NC_017312.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_017312.1"
    },

    # Kefir-Specific Examples
    {
        "Species/Strain": "Lactobacillus kefiranofaciens ZW3",
        "Typical Use / Role": "Kefir grains: produces kefiran exopolysaccharide",
        "GenBank Accession": "CP003677.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/CP003677.1"
    },
    {
        "Species/Strain": "Lactobacillus kefiri KCTC 3547",
        "Typical Use / Role": "Kefir grains: lactic acid production, flavor",
        "GenBank Accession": "CP032154.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/CP032154.1"
    },
    {
        "Species/Strain": "Leuconostoc mesenteroides subsp. mesenteroides ATCC 8293",
        "Typical Use / Role": "Kefir grains: produces CO₂ & diacetyl (aroma/flavor)",
        "GenBank Accession": "NC_008531.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_008531.1"
    },
    {
        "Species/Strain": "Acetobacter pasteurianus IFO 3283-01",
        "Typical Use / Role": "Kefir grains: acetic acid production (vinegary note)",
        "GenBank Accession": "NC_013209.1",
        "NCBI nuccore Link": "https://www.ncbi.nlm.nih.gov/nuccore/NC_013209.1"
    }
]

# Create a DataFrame
df = pd.DataFrame(data)

# Save to CSV (will download if running locally or in certain notebook environments).
df.to_csv("../metadata/Probiotic_Species_Strains.csv", index=False)

# Display the first few rows to confirm
df.head(10)
# Out:
#                                       Species/Strain  \
# 0                     Lactobacillus acidophilus NCFM
# 1                   Lactobacillus rhamnosus GG (LGG)
# 2      Lacticaseibacillus paracasei subsp. paracasei
# 3                  Lacticaseibacillus casei ATCC 334
# 4                Lactiplantibacillus plantarum WCFS1
# 5                         Lactobacillus reuteri F275
# 6                   Lactobacillus fermentum IFO 3956
# 7                  Lactobacillus helveticus DPC 4571
# 8  Lactobacillus delbrueckii subsp. bulgaricus AT...
# 9                      Lactobacillus brevis ATCC 367
#
#                                   Typical Use / Role GenBank Accession  \
# 0              Yogurts, fermented milks, supplements       NC_006814.1
# 1           Yogurt, dairy products, functional foods       NC_013198.1
# 2          Fermented milks, cheese, probiotic drinks       NC_037110.1
# 3  Fermented milk drinks (close relative to “Shir...       NC_008526.1
# ...
